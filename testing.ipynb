# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("testin using cash")

m = ["abril01", "abril02", "abril03", "abril04", "mayo00"];
ats = 3158 + 2800
acs = 7480 + ats
c = [100, 200, ats, acs, 0]

plt.plot(m, c)
# Out:
# testin using cash

# %%
t = np.linspace(0, 6*np.pi, 100)
f = np.exp(-0.1 * t)*np.sin(t)

plt.plot(t, f)
